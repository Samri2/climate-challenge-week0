# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Load data 
df = pd.read_csv('../data/ethiopia.csv', encoding='latin1', skiprows=[1])
print(df.shape)
df['Country'] = 'Ethiopia'
# Merge Year and Day of Year (DOY) into one 'Date' column
df['Date'] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")
df['Month'] = df['Date'].dt.month
df.head()

# %%
# Replace -999 with NaN (Not a Number)
df.replace(-999, np.nan, inplace=True)

# Check for duplicates (data housekeeping)
duplicates = df.duplicated().sum()
print(f"Found {duplicates} duplicate rows.")
df.drop_duplicates(inplace=True)
# stat summary
stats_summary = df[weather_cols].describe()
stats_summary
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[weather_cols])
plt.title("Distribution and Outliers of Ethiopia Weather Variables")
plt.show()

# Check for missing values (%)
missing_report = (df.isna().sum() / len(df)) * 100
print("Missing values percentage per column:")
print(missing_report)
